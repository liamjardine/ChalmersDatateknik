# %%
#imports
import sys
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets

# %% [markdown]
# ## Question 1

# %% [markdown]
# 1. Show the distribution of phi and psi combinations using:

# %%
#Load data into Dataframe
df = pd.read_csv('./assignment3-data-1.csv')

# %%
df_phi_psi = df.iloc[:, [3, 4]]
df_phi_psi
# Out:
#               phi         psi
# 0     -149.312855  142.657714
# 1      -44.283210  136.002076
# 2     -119.972621 -168.705263
# 3     -135.317212  137.143523
# 4     -104.851467   95.928520
# ...           ...         ...
# 29364 -147.749557  155.223562
# 29365 -117.428541  133.019506
# 29366 -113.586448  112.091970
# 29367 -100.668779  -12.102821
# 29368 -169.951240   94.233680
#
# [29369 rows x 2 columns]

# %% [markdown]
# a. A scatter plot

# %%
fig, ax = plt.subplots(figsize=(70, 50))

ax.set_title('Distribution of Φ (phi) and Ψ (psi)', size=100)
ax.set_xlabel('Φ (phi)', size=75)
ax.set_ylabel('Ψ (psi)', size=75)
ax.tick_params(axis='x', labelsize=75)
ax.tick_params(axis='y', labelsize=75)

array = df_phi_psi.to_numpy()
x = array[:, 0]
y = array[:, 1]
ax.scatter(x, y)

# %% [markdown]
# b. A heatmap

# %%
# Libraries
#import pandas as pd
#xfrom matplotlib import pyplot as plt
#xfrom scipy.cluster.hierarchy import dendrogram, linkage
#ximport numpy as np
#x 
#x# Import the mtcars dataset from the web + keep only numeric variables
#xdf = df.reset_index(drop=True)
#df = df.iloc[:, [1, 3, 4]]
#df
#
#import seaborn as sns; sns.set(color_codes=True)
#g = sns.heatmap(df)

# %% [markdown]
# 2. Use  the  K-means  clustering  method to  cluster  the  phi  and  psi  angle  combinations  in
# the data file.

# %% [markdown]
# a. Experiment with different values of K. Suggest an appropriate value of K for this
# task and motivate this choice.

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Perform K-Means clustering     
# Specify the number of clusters and fit the data X 

kmeans = KMeans(n_clusters=4, random_state=0).fit(df_phi_psi)
print(kmeans.cluster_centers_)

fig, ax = plt.subplots(figsize=(70, 50))

ax.set_title('Distribution of Φ (phi) and Ψ (psi)', size=100)
ax.set_xlabel('Φ (phi)', size=75)
ax.set_ylabel('Ψ (psi)', size=75)
ax.tick_params(axis='x', labelsize=75)
ax.tick_params(axis='y', labelsize=75)

array = df_phi_psi.to_numpy()
x = array[:, 0]
y = array[:, 1]
ax.scatter(x, y)
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=1000)
# Out:
# [[-105.28211144  134.99418244]
#  [ -82.84543221 -157.5452824 ]
#  [ -75.03528764  -25.58647919]
#  [  89.97103209   24.91969668]]

# %%
distortions = []
K = range(1,11)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(df_phi_psi)
    distortions.append(kmeanModel.inertia_)
     
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Perform K-Means clustering     
# Specify the number of clusters and fit the data X 

kmeans = KMeans(n_clusters=4, random_state=0).fit(df_phi_psi)
print(kmeans.cluster_centers_)

fig, ax = plt.subplots(figsize=(70, 50))

ax.set_title('Distribution of Φ (phi) and Ψ (psi)', size=100)
ax.set_xlabel('Φ (phi)', size=75)
ax.set_ylabel('Ψ (psi)', size=75)
ax.tick_params(axis='x', labelsize=75)
ax.tick_params(axis='y', labelsize=75)

array = df_phi_psi.to_numpy()
x = array[:, 0]
y = array[:, 1]
ax.scatter(x, y)
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', s=1000)
# Out:
# [[-105.28211144  134.99418244]
#  [ -82.84543221 -157.5452824 ]
#  [ -75.03528764  -25.58647919]
#  [  89.97103209   24.91969668]]

# %%
x = map(lambda x:x%180, array[:, 0])
x

# %% [markdown]
# b. Validate the clusters that are found with the chosen value of K.

# %% [markdown]
# We can validate the clustering using by checking the stability on the subsets, check for Co-occurence, the stability over repetitions and the silhouette coefficient. We will go through these step-by-step.

# %% [markdown]
# The stability on subsets is controlled by removing a proportion of some random points to see if clusters remain fundamentally the same.
